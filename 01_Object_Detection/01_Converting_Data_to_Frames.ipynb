# %%
import os
import cv2
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def get_frames(filename , num_frame = 1) :
    frames = []

    v_cap = cv2.VideoCapture(filename)

    v_len = int(v_cap.get(cv2.CAP_PROP_FRAME_COUNT))

    frame_list = np.linspace(0, v_len - 1, n_frames + 1, dtype=np.int16)

    for fn in range(v_len):
         success, frame = v_cap.read()
         if success is False:
             continue
         if fn in frame_list:
             frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
             frames.append(frame)
    v_cap.release()
    return frames , v_len

# %%
def store_frames(frames, path2store):
    for ii, frame in enumerate(frames):
        frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
        path2img = os.path.join(path2store, "frame"+str(ii)+".jpg")
        cv2.imwrite(path2img, frame)

# %%
n_frames = 1100
path2video = "/content/drive/MyDrive/Colab_Notebooks/Robot/01_Object_Detection/data/video_1.mp4"
print(path2video)
frames , vlen = get_frames(path2video , n_frames)
path2store = "/content/drive/MyDrive/Colab_Notebooks/Robot/01_Object_Detection/data/train/with_object"
print(path2store)
os.makedirs(path2store, exist_ok= True)
store_frames(frames, path2store)
# Out:
# /content/drive/MyDrive/Colab_Notebooks/Robot/01_Object_Detection/data/video_1.mp4

# %%
get_frames(filename = "try.avi" )
# Out:
# (79,
#  [array([[[ 23,  44,  40],
#           [ 25,  46,  42],
#           [ 31,  50,  44],
#           ...,
#           [ 31,  23,  12],
#           [ 24,  16,   5],
#           [ 23,  15,   4]],
#
#          [[ 28,  49,  45],
#           [ 29,  50,  46],
#           [ 35,  54,  48],
#           ...,
#           [ 35,  27,  16],
#           [ 30,  22,  11],
#           [ 28,  20,   9]],
#
#          [[ 31,  48,  43],
#           [ 27,  44,  39],
#           [ 27,  46,  40],
#           ...,
#           [ 32,  24,  13],
#           [ 36,  27,  19],
#           [ 36,  27,  19]],
#
#          ...,
#
#          [[136, 118,  29],
#           [137, 119,  30],
#           [135, 120,  30],
#           ...,
#           [ 17,  17,  12],
#           [ 17,  17,  14],
#           [ 16,  16,  13]],
#
#          [[134, 121,  28],
#           [134, 121,  28],
#           [135, 120,  28],
#           ...,
#           [ 34,  35,  25],
#           [ 34,  35,  27],
#           [ 34,  35,  27]],
#
# ...

# %%
import cv2

def get_frames(filename, num_frame=1):
    frames = []

    v_cap = cv2.VideoCapture(filename)

    v_len = int(v_cap.get(cv2.CAP_PROP_FRAME_COUNT))
    v_cap.release()  # Make sure to release the VideoCapture object

    return v_len  # ,frames
